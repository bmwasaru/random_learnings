# %%
import pandas as pd

payments = pd.read_csv('../data/Mobile Payments.csv').loc[:, ['Year', 'Month', 'Total Agent Cash in Cash Out (Value KSh billions)']]

# %%
payments.info()
payments.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 3 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Year                                               204 non-null    int64
#  1   Month                                              204 non-null    object
#  2   Total Agent Cash in Cash Out (Value KSh billions)  204 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 4.9+ KB
#    Year     Month  Total Agent Cash in Cash Out (Value KSh billions)
# 0  2024  February                                             790.80
# 1  2024   January                                             783.98
# 2  2023  December                                             788.35
# 3  2023  November                                             707.55
# ...

# %%
! pip install seaborn

import seaborn as sb
sb.relplot(x="Year", y="Total Agent Cash in Cash Out (Value KSh billions)",
           col="Month", data=payments)

# %%
X = payments['Year']
y = payments['Total Agent Cash in Cash Out (Value KSh billions)']

# %%
y
# Out:
# 0      790.800000
# 1      783.980000
# 2      788.350000
# 3      707.550000
# 4      703.280000
#           ...
# 199      1.065370
# 200      0.720102
# 201      0.483709
# 202      0.220896
# 203      0.064391
# Name: Total Agent Cash in Cash Out (Value KSh billions), Length: 204, dtype: float64
