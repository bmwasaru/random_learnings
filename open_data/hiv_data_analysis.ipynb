# %%
import pandas as pd

# %%
hiv = pd.read_csv('data/2014_Kenya_s_HIV_AIDS_profile_data_by_County.csv')
hiv.head() # first 5
# Out:
#         COUNTY NAME Adult (15+) HIV prevalence  \
# 0           BARINGO                         3%
# 1             BOMET                       5.8%
# 2           BUNGOMA                       3.2%
# 3             BUSIA                       6.8%
# 4  ELEGEYO-MARAKWET                       2.5%
#
#    New Hiv Infections (Adults 15+)  New Hiv Infections (Children 0-14)  \
# 0                              707                                  34
# 1                             1875                                  89
# 2                               83                                  93
# 3                               51                                  57
# 4                              400                                  19
#
#   ART Coverage  HIV+ Adults  Total Population Hiv Prevalence (men)  \
# 0          53%         9194          632588.0                 2.9%
# 1          38%        24389          824347.0                 4.5%
# ...

# %%
hiv.shape # number of counties (rows)
# Out:
# (47, 24)

# %%
hiv.columns
# Out:
# Index(['COUNTY NAME', 'Adult (15+) HIV prevalence',
#        'New Hiv Infections (Adults 15+)', 'New Hiv Infections (Children 0-14)',
#        'ART Coverage', 'HIV+ Adults', 'Total Population',
#        'Hiv Prevalence (men)', 'Hiv Prevalence (women)',
#        'POE-Prevention of mother-to-child transmission',
#        'POE-voluntering and testing', 'POE-Tuberculosis', 'POE-Medical ward',
#        'POE-Overral', 'Adults in need of ART', 'Adults receiving ART',
#        'Children in need of ART', 'Children receiving ART',
#        'No.of households with an  orphan', 'poor households with an orphan',
#        '(KES) cash transfer beneficiary poor households with an orphan',
#        'Aids related Deaths (15+)', 'Aids related Deaths (0-14)',
#        'Coordinates'],
#       dtype='object')

# %%
# summary statistics i.e the mean, count, max, std
hiv.describe()
# Out:
#        New Hiv Infections (Adults 15+)  New Hiv Infections (Children 0-14)  \
# count                        47.000000                           47.000000
# mean                       1885.787234                          272.914894
# std                        2737.390879                          618.337456
# min                          18.000000                            2.000000
# 25%                         365.000000                           27.500000
# 50%                         988.000000                           60.000000
# 75%                        1898.000000                           94.000000
# max                       12279.000000                         2700.000000
#
#          HIV+ Adults  Total Population  Adults in need of ART  \
# count      47.000000      4.600000e+01              47.000000
# mean    28633.659574      9.047307e+05           16189.000000
# std     32458.014449      6.071359e+05           20101.898206
# ...

# %%
# sort by number of new infection (children 0 -14) and get the top 5 counties
hiv.sort_values('New Hiv Infections (Children 0-14)').tail()
# Out:
#    COUNTY NAME Adult (15+) HIV prevalence  New Hiv Infections (Adults 15+)  \
# 15       KISII                         8%                             4891
# 26      MIGORI                      14.7%                             6786
# 37       SIAYA                      23.7%                             9869
# 16      KISUMU                      19.3%                            10349
# 7     HOMA BAY                      25.7%                            12279
#
#     New Hiv Infections (Children 0-14) ART Coverage  HIV+ Adults  \
# 15                                1075          48%        55970
# 26                                1492          89%        77650
# 37                                2170          82%       112962
# 16                                2276         104%       118538
# 7                                 2700          70%       140629
#
#     Total Population Hiv Prevalence (men) Hiv Prevalence (women)  \
# ...

# %%
# sort by number of new infections (Adults 15+) and get the top 5 counties
hiv.sort_values('New Hiv Infections (Adults 15+)').tail()
# Out:
#    COUNTY NAME Adult (15+) HIV prevalence  New Hiv Infections (Adults 15+)  \
# 15       KISII                         8%                             4891
# 26      MIGORI                      14.7%                             6786
# 37       SIAYA                      23.7%                             9869
# 16      KISUMU                      19.3%                            10349
# 7     HOMA BAY                      25.7%                            12279
#
#     New Hiv Infections (Children 0-14) ART Coverage  HIV+ Adults  \
# 15                                1075          48%        55970
# 26                                1492          89%        77650
# 37                                2170          82%       112962
# 16                                2276         104%       118538
# 7                                 2700          70%       140629
#
#     Total Population Hiv Prevalence (men) Hiv Prevalence (women)  \
# ...

# %%
# then number of new infections listing of top counties seem to be in the same order
# Does this mean the number of new adult and children infections are in the same order of in each county
hiv.sort_values('New Hiv Infections (Adults 15+)').head()
# Out:
#    COUNTY NAME Adult (15+) HIV prevalence  New Hiv Infections (Adults 15+)  \
# 45       WAJIR                       0.2%                               18
# 44      VIHIGA                       3.8%                               31
# 39  TANA RIVER                         1%                               40
# 20        LAMU                       2.3%                               44
# 3        BUSIA                       6.8%                               51
#
#     New Hiv Infections (Children 0-14) ART Coverage  HIV+ Adults  \
# 45                                   2          26%          307
# 44                                  35          97%         9853
# 39                                   4          97%         1161
# 20                                   5          95%         1263
# 3                                   57         183%        16065
#
#     Total Population Hiv Prevalence (men) Hiv Prevalence (women)  \
# ...

# %%
hiv.sort_values('New Hiv Infections (Children 0-14)').head()
# Out:
#    COUNTY NAME Adult (15+) HIV prevalence  New Hiv Infections (Adults 15+)  \
# 45       WAJIR                       0.2%                               18
# 39  TANA RIVER                         1%                               40
# 24    MARSABIT                       1.2%                               81
# 20        LAMU                       2.3%                               44
# 8       ISIOLO                       4.2%                              151
#
#     New Hiv Infections (Children 0-14) ART Coverage  HIV+ Adults  \
# 45                                   2          26%          307
# 39                                   4          97%         1161
# 24                                   4          86%         1480
# 20                                   5          95%         1263
# 8                                    8          60%         2822
#
#     Total Population Hiv Prevalence (men) Hiv Prevalence (women)  \
# ...

# %%
# where do we need to focus more on preventing mother to child infections?
hiv.sort_values('POE-Prevention of mother-to-child transmission').tail()
# Out:
#    COUNTY NAME Adult (15+) HIV prevalence  New Hiv Infections (Adults 15+)  \
# 15       KISII                         8%                             4891
# 32       NAROK                         5%                             1806
# 12      KIAMBU                       3.8%                             2931
# 19    LAIKIPIA                       3.7%                              692
# 36     SAMBURU                         5%                              461
#
#     New Hiv Infections (Children 0-14) ART Coverage  HIV+ Adults  \
# 15                                1075          48%        55970
# 32                                  86          38%        23504
# 12                                  95         102%        42425
# 19                                  33          54%         8963
# 36                                  22          24%         6001
#
#     Total Population Hiv Prevalence (men) Hiv Prevalence (women)  \
# ...

# %%
hiv.loc[:, ['COUNTY NAME', 'Adults receiving ART', 'Adults in need of ART', 'Aids related Deaths (15+)']]
# Out:
#          COUNTY NAME  Adults receiving ART  Adults in need of ART  \
# 0            BARINGO                  2406                   4498
# 1              BOMET                  4511                  11930
# 2            BUNGOMA                 10982                  17164
# 3              BUSIA                 19398                  10588
# 4   ELEGEYO-MARAKWET                   978                   2542
# 5               EMBU                  5130                   5540
# 6            GARISSA                   786                   1649
# 7           HOMA BAY                 46738                  70837
# 8             ISIOLO                   969                   1616
# 9            KAJIADO                  5219                   9827
# 10          KAKAMEGA                 21014                  31896
# 11           KERICHO                  9299                   7725
# 12            KIAMBU                 24104                  23747
# ...

# %%
# Do we have counties where the prevalence of HIV in women is 0%
hiv[hiv['Hiv Prevalence (women)'] == '0%']
# Out:
#    COUNTY NAME Adult (15+) HIV prevalence  New Hiv Infections (Adults 15+)  \
# 45       WAJIR                       0.2%                               18
#
#     New Hiv Infections (Children 0-14) ART Coverage  HIV+ Adults  \
# 45                                   2          26%          307
#
#     Total Population Hiv Prevalence (men) Hiv Prevalence (women)  \
# 45          434524.0                 0.1%                     0%
#
#    POE-Prevention of mother-to-child transmission  ... Adults in need of ART  \
# 45                                            38%  ...                   250
#
#    Adults receiving ART Children in need of ART Children receiving ART  \
# 45                   66                     114                      5
#
#     No.of households with an  orphan  poor households with an orphan  \
# 45                              9707                            4756
#
#     (KES) cash transfer beneficiary poor households with an orphan  \
# ...

# %%
# Whats the data on Mombasa county?
hiv[hiv['COUNTY NAME'] == 'MOMBASA']
# Out:
#    COUNTY NAME Adult (15+) HIV prevalence  New Hiv Infections (Adults 15+)  \
# 27     MOMBASA                       7.4%                             1609
#
#     New Hiv Infections (Children 0-14) ART Coverage  HIV+ Adults  \
# 27                                 169          98%        47751
#
#     Total Population Hiv Prevalence (men) Hiv Prevalence (women)  \
# 27         1068307.0                 4.5%                  10.5%
#
#    POE-Prevention of mother-to-child transmission  ... Adults in need of ART  \
# 27                                            35%  ...                 27168
#
#    Adults receiving ART Children in need of ART Children receiving ART  \
# 27                26490                    4817                   1995
#
#     No.of households with an  orphan  poor households with an orphan  \
# 27                             21546                           10557
#
#     (KES) cash transfer beneficiary poor households with an orphan  \
# ...

# %%
# ART among adults highest in which county?
hiv.sort_values('Adults receiving ART').tail()
# Out:
#    COUNTY NAME Adult (15+) HIV prevalence  New Hiv Infections (Adults 15+)  \
# 26      MIGORI                      14.7%                             6786
# 37       SIAYA                      23.7%                             9869
# 7     HOMA BAY                      25.7%                            12279
# 16      KISUMU                      19.3%                            10349
# 29     NAIROBI                       6.8%                             3098
#
#     New Hiv Infections (Children 0-14) ART Coverage  HIV+ Adults  \
# 26                                1492          89%        77650
# 37                                2170          82%       112962
# 7                                 2700          70%       140629
# 16                                2276         104%       118538
# 29                                 313          92%       102828
#
#     Total Population Hiv Prevalence (men) Hiv Prevalence (women)  \
# ...

# %%
# ART among children highest in which county?
hiv.sort_values('Children receiving ART').tail()
# Out:
#    COUNTY NAME Adult (15+) HIV prevalence  New Hiv Infections (Adults 15+)  \
# 26      MIGORI                      14.7%                             6786
# 37       SIAYA                      23.7%                             9869
# 7     HOMA BAY                      25.7%                            12279
# 16      KISUMU                      19.3%                            10349
# 29     NAIROBI                       6.8%                             3098
#
#     New Hiv Infections (Children 0-14) ART Coverage  HIV+ Adults  \
# 26                                1492          89%        77650
# 37                                2170          82%       112962
# 7                                 2700          70%       140629
# 16                                2276         104%       118538
# 29                                 313          92%       102828
#
#     Total Population Hiv Prevalence (men) Hiv Prevalence (women)  \
# ...

# %%
hiv.sort_values('Children receiving ART').head()
# Out:
#    COUNTY NAME Adult (15+) HIV prevalence  New Hiv Infections (Adults 15+)  \
# 45       WAJIR                       0.2%                               18
# 23     MANDERA                       1.7%                              137
# 39  TANA RIVER                         1%                               40
# 36     SAMBURU                         5%                              461
# 6      GARISSA                       2.1%                              116
#
#     New Hiv Infections (Children 0-14) ART Coverage  HIV+ Adults  \
# 45                                   2          26%          307
# 23                                  17           4%         3928
# 39                                   4          97%         1161
# 36                                  22          24%         6001
# 6                                   14          48%         3262
#
#     Total Population Hiv Prevalence (men) Hiv Prevalence (women)  \
# ...

# %%
hiv.sort_values('Adults receiving ART').head()
# Out:
#    COUNTY NAME Adult (15+) HIV prevalence  New Hiv Infections (Adults 15+)  \
# 45       WAJIR                       0.2%                               18
# 23     MANDERA                       1.7%                              137
# 39  TANA RIVER                         1%                               40
# 36     SAMBURU                         5%                              461
# 20        LAMU                       2.3%                               44
#
#     New Hiv Infections (Children 0-14) ART Coverage  HIV+ Adults  \
# 45                                   2          26%          307
# 23                                  17           4%         3928
# 39                                   4          97%         1161
# 36                                  22          24%         6001
# 20                                   5          95%         1263
#
#     Total Population Hiv Prevalence (men) Hiv Prevalence (women)  \
# ...
